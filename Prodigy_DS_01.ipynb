# %% [markdown]
# <a href="https://colab.research.google.com/github/piikkkuuuu/ProgrammingAssignment2/blob/master/Prodigy_DS_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample population data
data = {
    'Age': [25, 30, 22, 35, 29, 40, 36, 28, 32, 23, 24, 41, 27, 26, 33],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female',
               'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male']
}

df = pd.DataFrame(data)

# --------------------
# Bar Chart: Gender Distribution
# --------------------
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=df, palette='Set2')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()

# --------------------
# Histogram: Age Distribution
# --------------------
plt.figure(figsize=(6, 4))
sns.histplot(df['Age'], bins=7, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipython-input-1-3870939416.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='Set2')
